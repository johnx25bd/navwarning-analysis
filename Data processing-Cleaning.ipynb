# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import re
import os
#import nltk
from nltk.corpus import stopwords

# %%
stopWords = stopwords.words('english')

# %%
directory = 'C:/Users/Krist/University College London/Spatio-Temporal Data Analysis and Data Mining/Data-Nav'
i = 0

for filename in os.listdir(directory):
    
    if i == 0:
        combinedData = gpd.read_file('Data-Nav/'+filename)
    else:
        data1 = gpd.read_file('Data-Nav/'+filename)
        combinedData = pd.concat([combinedData,data1])
    i += 1

combinedData = combinedData.reset_index(drop=True)

# %%
combinedData
# Out:
#                                                name  \
# 0                          HYDROARC 112/12 [1 of 1]
# 1                          HYDROARC 193/12 [1 of 2]
# 2                          HYDROARC 193/12 [2 of 2]
# 3           HYDROARC 131/14 [1 of 1][[WWNWSFOLDER]]
# 4           HYDROARC 268/14 [1 of 1][[WWNWSFOLDER]]
# 5           HYDROARC 269/14 [1 of 1][[WWNWSFOLDER]]
# 6           HYDROARC 343/15 [1 of 1][[WWNWSFOLDER]]
# 7           HYDROARC 345/15 [1 of 2][[WWNWSFOLDER]]
# 8           HYDROARC 345/15 [2 of 2][[WWNWSFOLDER]]
# 9           HYDROARC 155/16 [1 of 2][[WWNWSFOLDER]]
# 10          HYDROARC 155/16 [2 of 2][[WWNWSFOLDER]]
# 11          HYDROARC 205/16 [1 of 4][[WWNWSFOLDER]]
# 12          HYDROARC 205/16 [2 of 4][[WWNWSFOLDER]]
# 13          HYDROARC 205/16 [3 of 4][[WWNWSFOLDER]]
# 14          HYDROARC 205/16 [4 of 4][[WWNWSFOLDER]]
# 15          HYDROARC 139/17 [1 of 3][[WWNWSFOLDER]]
# 16          HYDROARC 139/17 [2 of 3][[WWNWSFOLDER]]
# 17          HYDROARC 139/17 [3 of 3][[WWNWSFOLDER]]
# 18          HYDROARC 188/17 [1 of 1][[WWNWSFOLDER]]
# 19          HYDROARC 189/17 [1 of 1][[WWNWSFOLDER]]
# 20          HYDROARC 228/17 [1 of 3][[WWNWSFOLDER]]
# 21          HYDROARC 228/17 [2 of 3][[WWNWSFOLDER]]
# 22          HYDROARC 228/17 [3 of 3][[WWNWSFOLDER]]
# 23          HYDROARC 267/17 [1 of 1][[WWNWSFOLDER]]
# 24          HYDROARC 274/17 [1 of 7][[WWNWSFOLDER]]
# 25          HYDROARC 274/17 [2 of 7][[WWNWSFOLDER]]
# 26          HYDROARC 274/17 [3 of 7][[WWNWSFOLDER]]
# 27          HYDROARC 274/17 [4 of 7][[WWNWSFOLDER]]
# 28          HYDROARC 274/17 [5 of 7][[WWNWSFOLDER]]
# 29          HYDROARC 274/17 [6 of 7][[WWNWSFOLDER]]
# ...                                             ...
# 53926   NAVAREA XII 271/17 [6 of 10][[WWNWSFOLDER]]
# 53927   NAVAREA XII 271/17 [7 of 10][[WWNWSFOLDER]]
# 53928   NAVAREA XII 271/17 [8 of 10][[WWNWSFOLDER]]
# 53929   NAVAREA XII 271/17 [9 of 10][[WWNWSFOLDER]]
# 53930  NAVAREA XII 271/17 [10 of 10][[WWNWSFOLDER]]
# 53931    NAVAREA XII 312/17 [1 of 2][[WWNWSFOLDER]]
# 53932    NAVAREA XII 312/17 [2 of 2][[WWNWSFOLDER]]
# 53933    NAVAREA XII 519/17 [1 of 7][[WWNWSFOLDER]]
# 53934    NAVAREA XII 519/17 [2 of 7][[WWNWSFOLDER]]
# 53935    NAVAREA XII 519/17 [3 of 7][[WWNWSFOLDER]]
# 53936    NAVAREA XII 519/17 [4 of 7][[WWNWSFOLDER]]
# 53937    NAVAREA XII 519/17 [5 of 7][[WWNWSFOLDER]]
# 53938    NAVAREA XII 519/17 [6 of 7][[WWNWSFOLDER]]
# 53939    NAVAREA XII 519/17 [7 of 7][[WWNWSFOLDER]]
# 53940    NAVAREA XII 115/18 [1 of 1][[WWNWSFOLDER]]
# 53941    NAVAREA XII 167/18 [1 of 1][[WWNWSFOLDER]]
# 53942    NAVAREA XII 341/18 [1 of 3][[WWNWSFOLDER]]
# 53943    NAVAREA XII 341/18 [2 of 3][[WWNWSFOLDER]]
# 53944    NAVAREA XII 341/18 [3 of 3][[WWNWSFOLDER]]
# 53945    NAVAREA XII 349/18 [1 of 1][[WWNWSFOLDER]]
# 53946    NAVAREA XII 371/18 [1 of 1][[WWNWSFOLDER]]
# 53947    NAVAREA XII 409/18 [1 of 1][[WWNWSFOLDER]]
# 53948    NAVAREA XII 415/18 [1 of 1][[WWNWSFOLDER]]
# 53949    NAVAREA XII 417/18 [1 of 2][[WWNWSFOLDER]]
# 53950    NAVAREA XII 417/18 [2 of 2][[WWNWSFOLDER]]
# 53951    NAVAREA XII 419/18 [1 of 1][[WWNWSFOLDER]]
# 53952    NAVAREA XII 421/18 [1 of 3][[WWNWSFOLDER]]
# 53953    NAVAREA XII 421/18 [2 of 3][[WWNWSFOLDER]]
# 53954    NAVAREA XII 421/18 [3 of 3][[WWNWSFOLDER]]
# 53955    NAVAREA XII 422/18 [1 of 1][[WWNWSFOLDER]]
#
#                                              description   styleUrl  \
# 0      <B>CANADA-NORTH COAST.  <br>\nBEAUFORT SEA. <b...  #NavWarnP
# 1      <B>ARCTIC. <br>\nBEAUFORT SEA. <br>\nCHART 159...  #NavWarnP
# 2      <B>ARCTIC. <br>\nBEAUFORT SEA. <br>\nCHART 159...  #NavWarnP
# 3      <B>ARCTIC.<br>\nCHUCKCHI SEA.<br>\nCHART 16003...  #NavWarnP
# 4      <B>ARCTIC.<br>\nCHUKCHI SEA.<br>\nCHART 16003....  #NavWarnP
# 5      <B>ARCTIC.<br>\nCHUKCHI SEA.<br>\nCHART 16003....  #NavWarnP
# 6      <B>ARCTIC.<br>\nBEAUFORT SEA.<br>\nDNC 27.<br>...  #NavWarnP
# 7      <B>ARCTIC.<br>\nBEAUFORT SEA.<br>\nDNC 27.<br>...  #NavWarnP
# 8      <B>ARCTIC.<br>\nBEAUFORT SEA.<br>\nDNC 27.<br>...  #NavWarnP
# 9      <B>ARCTIC.<br>\nCHUKCHI SEA.<br>\nDNC 27.<br>\...  #NavWarnP
# 10     <B>ARCTIC.<br>\nCHUKCHI SEA.<br>\nDNC 27.<br>\...  #NavWarnP
# 11     <B>ARCTIC.<br>\nBEAUFORT SEA.<br>\nCHUKCHI SEA...  #NavWarnP
# 12     <B>ARCTIC.<br>\nBEAUFORT SEA.<br>\nCHUKCHI SEA...  #NavWarnP
# 13     <B>ARCTIC.<br>\nBEAUFORT SEA.<br>\
# 53955  (LINESTRING Z (-119.118056 34.1075 0, -119.081...
#
# [53956 rows x 4 columns]

# %%
trainingset = np.random.randint(0,combinedData.shape[0],10000)
trainingDataFrame = combinedData.loc[trainingset]
trainingDataFrame = trainingDataFrame.reset_index()#drop=True

# %%
trainingDataFrame
# Out:
#       index                                         name  \
# 0      7579     HYDROPAC 3813/17 [1 of 7][[WWNWSFOLDER]]
# 1      4332      HYDROARC 121/18 [1 of 1][[WWNWSFOLDER]]
# 2     47904     HYDROPAC 2571/18 [1 of 1][[WWNWSFOLDER]]
# 3     36607     HYDROPAC 2279/18 [1 of 1][[WWNWSFOLDER]]
# 4     28305     HYDROPAC 2507/18 [3 of 3][[WWNWSFOLDER]]
# 5     47052  HYDROLANT 1706/17 [11 of 14][[WWNWSFOLDER]]
# 6     27719    NAVAREA IV 170/17 [2 of 5][[WWNWSFOLDER]]
# 7     51282    NAVAREA IV 124/17 [3 of 5][[WWNWSFOLDER]]
# 8     47574   NAVAREA XII 167/18 [1 of 1][[WWNWSFOLDER]]
# 9     26039    HYDROLANT 2447/18 [1 of 1][[WWNWSFOLDER]]
# 10     3136     HYDROPAC 3230/16 [1 of 1][[WWNWSFOLDER]]
# 11    23187    HYDROLANT 2340/18 [1 of 1][[WWNWSFOLDER]]
# 12     2840      HYDROARC 274/17 [2 of 7][[WWNWSFOLDER]]
# 13    25943     HYDROLANT 806/18 [1 of 1][[WWNWSFOLDER]]
# 14    22152   NAVAREA IV 537/18 [9 of 15][[WWNWSFOLDER]]
# 15    31702      HYDROARC 183/18 [7 of 7][[WWNWSFOLDER]]
# 16    44756     HYDROPAC 3310/18 [4 of 5][[WWNWSFOLDER]]
# 17    49287     HYDROPAC 3399/18 [1 of 1][[WWNWSFOLDER]]
# 18    34116    HYDROLANT 2162/18 [1 of 1][[WWNWSFOLDER]]
# 19    43428     HYDROPAC 3222/18 [1 of 1][[WWNWSFOLDER]]
# 20    28547   NAVAREA IV 537/18 [6 of 15][[WWNWSFOLDER]]
# 21     1952    NAVAREA IV 612/17 [1 of 1][[WWNWSFOLDER]]
# 22    34556    NAVAREA IV 150/18 [1 of 1][[WWNWSFOLDER]]
# 23    30323    HYDROLANT 2457/18 [1 of 1][[WWNWSFOLDER]]
# 24    40449     HYDROPAC 3107/18 [1 of 1][[WWNWSFOLDER]]
# 25    17187    HYDROLANT 1390/13 [1 of 1][[WWNWSFOLDER]]
# 26    36295      HYDROARC 147/18 [3 of 5][[WWNWSFOLDER]]
# 27    13632     HYDROLANT 730/18 [1 of 1][[WWNWSFOLDER]]
# 28    10957    HYDROLANT 1975/18 [1 of 1][[WWNWSFOLDER]]
# 29    52914    HYDROLANT 3035/18 [1 of 1][[WWNWSFOLDER]]
# ...     ...                                          ...
# 9970  17490     HYDROPAC 1524/18 [2 of 2][[WWNWSFOLDER]]
# 9971  16698      HYDROPAC 570/17 [1 of 1][[WWNWSFOLDER]]
# 9972  34032    HYDROLANT 1492/17 [3 of 4][[WWNWSFOLDER]]
# 9973   6064     HYDROPAC 1392/17 [1 of 1][[WWNWSFOLDER]]
# 9974  35765     HYDROPAC 3214/16 [1 of 1][[WWNWSFOLDER]]
# 9975  14732    NAVAREA IV 124/17 [1 of 5][[WWNWSFOLDER]]
# 9976  40081      HYDROARC 186/18 [1 of 1][[WWNWSFOLDER]]
# 9977  36355    HYDROLANT 4193/17 [1 of 1][[WWNWSFOLDER]]
# 9978   8468    NAVAREA IV 124/17 [3 of 5][[WWNWSFOLDER]]
# 9979  14266      HYDROARC 146/18 [5 of 6][[WWNWSFOLDER]]
# 9980   9366      HYDROARC 267/17 [1 of 1][[WWNWSFOLDER]]
# 9981   9077     HYDROPAC 2193/18 [1 of 1][[WWNWSFOLDER]]
# 9982  40255    HYDROLANT 2772/18 [1 of 1][[WWNWSFOLDER]]
# 9983  27578     HYDROPAC 2408/18 [1 of 1][[WWNWSFOLDER]]
# 9984  28803    HYDROLANT 1456/18 [1 of 1][[WWNWSFOLDER]]
# 9985  44140    NAVAREA IV 108/17 [3 of 4][[WWNWSFOLDER]]
# 9986  16434      HYDROARC 114/18 [1 of 3][[WWNWSFOLDER]]
# 9987  32558    HYDROLANT 1643/18 [1 of 1][[WWNWSFOLDER]]
# 9988  29979    NAVAREA IV 173/18 [1 of 1][[WWNWSFOLDER]]
# 9989  27185    NAVAREA XII 96/18 [1 of 1][[WWNWSFOLDER]]
# 9990  49210     HYDROPAC 3107/18 [1 of 1][[WWNWSFOLDER]]
# 9991  48512    HYDROLANT 3001/18 [1 of 1][[WWNWSFOLDER]]
# 9992  49521   NAVAREA XII 519/17 [3 of 7][[WWNWSFOLDER]]
# 9993  40527     NAVAREA IV 68/17 [2 of 2][[WWNWSFOLDER]]
# 9994  12031    NAVAREA IV 462/18 [1 of 3][[WWNWSFOLDER]]
# 9995  23929    HYDROLANT 2409/18 [2 of 5][[WWNWSFOLDER]]
# 9996  40640    NAVAREA IV 224/18 [1 of 1][[WWNWSFOLDER]]
# 9997   8705    HYDROLANT 1316/17 [1 of 2][[WWNWSFOLDER]]
# 9998  33763  NAVAREA IV 1083/17 [1 of 12][[WWNWSFOLDER]]
# 9999  30367    HYDROLANT 2573/18 [1 of 1][[WWNWSFOLDER]]
#
#                                             description   styleUrl  \
# 0     <B>SOUTH CHINA SEA.<br>\nVIETNAM.<br>\nDNC 11....  #NavWarnP
# 1     <B>BARENTS SEA.<br>\nRUSSIA.<br>\nDNC 22.</B><...  #NavWarnL
# 2     <B>PHILIPPINE SEA.<br>\nDNC 12.<br>\nCHART 970...  #NavWarnL
# 3     <B>EASTERN SOUTH PACIFIC. <br>\nCHILE. <br>\nD...  #NavWarnP
# 4     <B>SEA OF OKHOTSK. <br>\nSAKHALIN. <br>\nDNC 2...  #NavWarnL
# 5     <B>NORTH SEA.<br>\nSHETLAND ISLANDS.<br>\nDNC ...  #NavWarnP
# 6     <B>EASTERN CARIBBEAN SEA.<br>\nANGUILLA.<br>\n...  #NavWarnP
# 7     <B>EASTERN CARIBBEAN SEA.<br>\nANGUILLA.<br>\n...  #NavWarnP
# 14                      POINT Z (-56.157667 6.225667 0)
# 15                     POINT Z (108.298334 77.478334 0)
# 16    (LINESTRING Z (82.166667 0 0, 83.5 -0.333333 0...
# 17                               POINT Z (106.05 8.6 0)
# 18                       POINT Z (-40.021667 -20.285 0)
# 19    (LINESTRING Z (89 20 0, 88 20 0, 88 20.583334 ...
# 20                      POINT Z (-55.760167 6.175667 0)
# 21             POINT Z (-67.34833399999999 10.536667 0)
# 22                        POINT Z (-71.641667 17.475 0)
# 23    (LINESTRING Z (32.166667 44.666667 0, 32.08333...
# 24                        POINT Z (72.7135 20.670167 0)
# 25    (LINESTRING Z (40.006 43.384667 0, 39.809 43.2...
# 26                     POINT Z (162.297223 69.655556 0)
# 27                    POINT Z (-50.136667 -30.008333 0)
# 28    (LINESTRING Z (-7.166667 51.483334 0, -7.58333...
# 29                             POINT Z (18.61 35.655 0)
# ...                                                 ...
# 9970                   POINT Z (57.808667 -20.301833 0)
# 9971                   POINT Z (106.873334 20.668334 0)
# 9972                       POINT Z (-1.038334 60.259 0)
# 9973                    POINT Z (142.971667 6.688334 0)
# 9974                    POINT Z (72.436667 21.650834 0)
# 9975                      POINT Z (-63.253334 18.285 0)
# 9976  (LINESTRING Z (-133.047667 69.442667 0, -132.9...
# 9977  (LINESTRING Z (21.666667 36.8 0, 21.833334 36....
# 9978                      POINT Z (-63.145 18.283334 0)
# 9979           POINT Z (162.200556 69.64916700000001 0)
# 9980                   POINT Z (-96.360834 68.413667 0)
# 9981                    POINT Z (50.651667 26.215334 0)
# 9982  (LINESTRING Z (-39.666667 -21.1 0, -40.216667 ...
# 9983                         POINT Z (-73.83 -52.915 0)
# 9984                   POINT Z (-17.503334 14.723334 0)
# 9985                     POINT Z (-61.6025 12.208334 0)
# 9986                          POINT Z (-68.545 63.73 0)
# 9987                        POINT Z (-50.116667 0.76 0)
# 9988           POINT Z (-88.19805599999999 17.354445 0)
# 9989                    POINT Z (-78.713334 1.853334 0)
# 9990                      POINT Z (72.7135 20.670167 0)
# 9991                        POINT Z (2.375 51.911667 0)
# 9992                    POINT Z (-78.756112 1.876389 0)
# 9993                       POINT Z (-61.5625 12.3315 0)
# 9994                          POINT Z (-68.545 63.73 0)
# 9995                       POINT Z (-54.9 -62.366666 0)
# 9996              POINT Z (-69.80166699999999 11.945 0)
# 9997                        POINT Z (1.596667 52.095 0)
# 9998           POINT Z (-57.130667 8.154999999999999 0)
# 9999  (LINESTRING Z (-39.666667 -21.1 0, -40.216667 ...
#
# [10000 rows x 5 columns]

# %%
#data = gpd.read_file('navwarning/json/NAVWARN.json')
indcies = combinedData.index
descriptionFrame = pd.DataFrame(index=indcies, columns=['Area','Chart', 'Message','Authority','Date'])
#descriptionFrame_1 = pd.DataFrame(index=indcies, columns=['Area','Chart', 'Message','Authority','Date'])

# %%
def handleNoChartObs(noChartsObsList,noChartDataFrame,finalDataFrame,messageWords,areaWords,succesfulObs):
    
    additionsWords = []
    additionsAreas = []

    minTempEle = 1000
    maxTempEle = 0
    
    numberWithoutArea = 0
    numberWithoutMessage = 0
    
    for ele in noChartDataFrame.index:

        tempobs = noChartsObsList[ele]

        # Setting up our comparisonFrame
        compare = pd.DataFrame(index=np.arange(len(tempobs)),columns=['message','area'])
        replaceindex = noChartDataFrame['index'].loc[ele]
        p = 0

        for subele in tempobs:
            # Checking if it is time to store the 'Authority' index
            if 'Aut' in subele:
                aut = p
            # Checking if it is time to store the 'Date' index
            if 'Date' in subele:
                dat = p

            messageprob = 0
            areaprob = 0

            # Cleaning up individual words
            tempele = re.split('[ ]',subele)
            tempele = [re.sub('[ :,.0-9-/]','',s) for s in tempele]
            tempele = [re.sub('.//','',s) for s in tempele]
            tempele = [i for i in tempele if i != '']
            
            k = 0
            l = 0
            # Extracting probabilities that a element in 'tempobs' is either an area element or a message element.
            for subsubele in tempele:
                # Standard Score metric
                try:
                    messageprob += messageWords[subsubele]/succesfulObs
                    #k += 1
                except:
                    messageprob = 0

                try:
                    areaprob += areaWords[subsubele]/succesfulObs
                    #l += 1
                except:
                    areaprob = 0
            # Storing in of comparisonFrame
            
            # Probabilitiy metric
#             if k > 0:
#                 compare['message'].loc[p] = messageprob/k
#             else:
#                 compare['message'].loc[p] = 0
            
#             if l > 0:
#                 compare['area'].loc[p] = areaprob/l
#             else:
#                 compare['area'].loc[p] = 0
            # Score Metric
            compare['message'].loc[p] = messageprob
            compare['area'].loc[p] = areaprob
            p += 1
            
        # Extracting the needed indices
        areaindex = list(compare.index[compare['area']>compare['message']])
        messageindex = list(compare.index[compare['area']<=compare['message']])

        if areaindex != [] and messageindex != []:
         
            while(min(messageindex) < min(areaindex)):
                wrongindex = min(messageindex)
                messageindex.remove(wrongindex)
                areaindex.append(wrongindex)
            while(max(areaindex) in np.arange(min(messageindex),max(messageindex))):
                wrongIndex = max(areaindex)
                areaindex.remove(wrongIndex)
                messageindex.append(wrongIndex)
    
            # Removing the indices for 'Authority' and ' Date'
            if aut in areaindex:
                areaindex.remove(aut)
            elif aut in messageindex:
                messageindex.remove(aut)

            if dat in areaindex:
                areaindex.remove(dat)
            elif dat in messageindex:
                messageindex.remove(dat)

            # Joining together the new area and message variable
            # Adding the individual words for new areas/messages to the frequency count
              
            area = '/'.join(tempobs[min(areaindex):max(areaindex)+1])
            tempaddAreas = re.split('[ ./]',area)
            tempaddAreas = [i for i in tempaddAreas if i != '' and len(re.findall('[0-9]',i)) == 0]
            tempaddAreas = list(set(tempaddAreas))

            # Counting the frequency of each word in the areas
            for a in tempaddAreas:

                if a not in areaWords.keys():
                    areaWords[a] = 1
                else:

                    areaWords[a] += 1
        
            message = ' '.join(tempobs[min(messageindex):max(messageindex)+1])
            tempaddWords = re.split('[ ./]',message)
            tempaddWords = [i for i in tempaddWords if i != '' and len(re.findall('[0-9]',i)) == 0]
            tempaddWords = list(set(tempaddWords))

            # Counting the frequency of each word in the messages
            for w in tempaddWords:

                if w not in messageWords.keys():
                    messageWords[w] = 1
                else:
                    messageWords[w] += 1
                    
            succesfulObs += 1
        
        elif areaindex == [] and messageindex != []:
            
            # Removing the indices for 'Authority' and ' Date'
            if aut in messageindex:
                messageindex.remove(aut)

            if dat in messageindex:
                messageindex.remove(dat)
                
            message = ' '.join(tempobs[min(messageindex):max(messageindex)+1])
            tempaddWords = re.split('[ ./]',message)
            tempaddWords = [i for i in tempaddWords if i != '' and len(re.findall('[0-9]',i)) == 0]
            tempaddWords = list(set(tempaddWords))

            # Counting the frequency of each word in the messages
            for w in tempaddWords:

                if w not in messageWords.keys():
                    messageWords[w] = 1
                else:
                    messageWords[w] += 1
            
            numberWithoutArea += 1
        
        elif areaindex != [] and messageindex == []:
            # Removing the indices for 'Authority' and ' Date'
            if aut in areaindex:
                areaindex.remove(aut)

            if dat in areaindex:
                areaindex.remove(dat)
            
            area = '/'.join(tempobs[min(areaindex):max(areaindex)+1])
            tempaddAreas = re.split('[ ./]',area)
            tempaddAreas = [i for i in tempaddAreas if i != '' and len(re.findall('[0-9]',i)) == 0]
            tempaddAreas = list(set(tempaddAreas))

            # Counting the frequency of each word in the areas
            for a in tempaddAreas:

                if a not in areaWords.keys():
                    areaWords[a] = 1
                else:

                    areaWords[a] += 1
            
            numberWithoutMessage += 1
                    
        else:
            print('Error in ',replaceindex)
            
        # Throwing the newly created variables into the 'descriptionFrame' at the correct locations

        finalDataFrame['Area'].loc[replaceindex] = area
        finalDataFrame['Message'].loc[replaceindex] = message
        
        #return area,message
    print('Number of observations without "Area" is: ' , numberWithoutArea)
    print('Number of observations without "Message" is: ' , numberWithoutMessage)
    print('Number of observations succesful is: ' , succesfulObs)
    return finalDataFrame,succesfulObs,messageWords,areaWords#,maxTempEle,minTempEle

# %%
messagewords = {}
areawords = {}
nocharttemp = []
chartwords = []

# maxLenW = 0
# minLenW = 1000
maxLenA = 0
minLenA = 1000
areaLength = []
# let's make that nice-ass-looking dataframe with all our observations

for obs in indcies:
    
    chartindex = 0
    
    temp = re.split('[<>]',combinedData['description'].loc[obs])#trainingDataFrame
    temp = [ele for ele in temp if ele not in ['B','','br','/B',' ']]
    temp = [re.sub('[\n]','',ele) for ele in temp]
#     if obs == 0 or obs == 668:
#         print(temp)
#         print('')
    ############################################## Finding the authority ################################################
    
    authority = [ele for ele in temp if 'Authority' in ele]
    
    # If no 'authority' variable is present or no information follows
    if authority == [] or re.split(' ',authority[0])[1] == '':
        
        authority = 'No authority registered'
        
    # If the information is present, we extract the everything after 'authority'
    else:
        
        authority = re.split(' ',authority[0])
        steps = np.arange(len(authority))
        
        skipindex = [index for index in steps if authority[index]=='Authority:']
        
        authority = ' '.join(authority[skipindex[0]+1:])
        
    ############################################## Finding the date #####################################################
    
    date = [ele for ele in temp if 'Date' in ele]
    
    if ((date == [] or len(date)>=2)) and authority != 'No authority registered':
        
        # Getting the date from the 'authority' variable
        tempaut = re.split('[^a-zA-Z0-9]',authority)#temp[-2]
        tempaut = [ele for ele in tempaut if ele not in ['',' ']]
        
        date = ' '.join(tempaut[len(tempaut)-2:])
    
    else:
        
        # Getting the date form the 'date' variable
        date = re.split(' ',date[0])
        steps = np.arange(len(date))
        
        skipindex = [index for index in steps if date[index]=='Date:']
        
        date = ' '.join(date[skipindex[0]+1:])

    ############################################## Finding the chart index ################################################
       
    chartindex = [i for i in np.arange(len(temp)) if 'CHART' in temp[i]]
    
    if chartindex == []:
        chart = 'NO CHART'
        chartindex = ''
        nocharttemp.append(temp)
    else:
        
        chartindex = chartindex[0]
        chart = temp[chartindex]
        
    try:
        area = '/'.join(temp[:chartindex])
    except:
        area = ''
    
    # Extracting and combing the message
        
    message = []
    
    if chartindex != '':
        
        for i in np.arange(chartindex + 1,len(temp)):

            if '//' in temp[i]:
                message.append(temp[i])
                break
            else:
                message.append(temp[i])
                
    # Joining the message together
    message = ' '.join(message)
    
    # Getting each word in a list
    words = re.split('[ ]', message)
    areas = re.split('[ /]', area)
    charts = re.split(' ', chart)

    # Cleaning
    words = [i for i in words if i not in ["", " "] and len(re.findall('[0-9]',i)) == 0]
    words = [re.sub('[.:, ]','',i) for i in words]
    words = [re.sub('.//','',i) for i in words]
    words = [i for i in words if i != '']
    # Getting unique values
    words = list(set(words))
    
    areas = [i for i in areas if i not in ["", " "] and len(re.findall('[0-9]',i)) == 0]
    areas = [re.sub('[.:, ]','',i) for i in areas]
    areas = [re.sub('.//','',i) for i in areas]
    areas = [i for i in areas if i != '']
    
    areaLength.append(len(areas))
    
    if len(words)>maxLenA:
        maxLenA = len(areas)
    elif len(areas)<minLenA:
        minLenA = len(areas)
    
    # Getting unique values
    areas = list(set(areas))

    # Counting the frequency of each word in the messages
    for w in words:
                    
        if w not in messagewords.keys():
            messagewords[w] = 1
        else:
            messagewords[w] += 1

    # Counting the frequency of each word in the areas
    for a in areas:
             
        if a not in areawords.keys():
            areawords[a] = 1
        else:

            areawords[a] += 1
                
#     # Adding this particular observation to the dataframe.
    descriptionFrame.loc[obs] = [area,chart,message,authority,date]
    
# Time to go over those observations which didn't had a 'chart' variable

nochart = descriptionFrame[descriptionFrame['Chart']=='NO CHART']
nochart = nochart.reset_index()
succesful = (descriptionFrame.shape[0]-nochart.shape[0])
print('All observations has been processed the first time, and %i observations did not have a "chart" variable to ensure a correct separation of the message.' % nochart.shape[0])
print('Those %i observations will now be processed again, using knowledge from the remaining %i observations.' % (nochart.shape[0],succesful))   

#maxtemp = handleNoChartObs(nocharttemp,nochart,descriptionFrame,messagewords,areawords,succesful)[4]
#mintemp = handleNoChartObs(nocharttemp,nochart,descriptionFrame,messagewords,areawords,succesful)[5]

dataFrame, succesObs, messageWordCount,areaWordsCount = handleNoChartObs(nocharttemp,nochart,descriptionFrame,messagewords,areawords,succesful)
# Out:
# All observations has been processed the first time, and 22265 observations did not have a "chart" variable to ensure a correct separation of the message.
# Those 22265 observations will now be processed again, using knowledge from the remaining 31691 observations.
# Number of observations without "Area" is:  101
# Number of observations without "Message" is:  0
# Number of observations succesful is:  53855

# %%
dataFrame.to_csv('CleanedData.csv')

# %%
areaWordsSubset = {}
areaWordsInMessage = 0
for key in areaWordsCount.keys():
    if key in messageWordCount.keys():
        areaWordsInMessage += 1
        areaWordsSubset[key] = areaWordsCount[key]
#areaWordsSubset
areaWordsInMessage/len(messageWordCount.keys())
# Out:
# 0.04188034188034188
